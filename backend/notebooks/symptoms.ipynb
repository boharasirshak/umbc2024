# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
df = pd.read_csv("../symptoms.csv", index_col=0)
df.head()
# Out:
#               Diagnosis  Upper abdominal pain  Lower abdominal pain  \
# 0         Cholecystitis                     1                     1
# 11  Choledocholithiasis                     1                     0
# 15       Cholelithiasis                     1                     1
# 28         Constipation                     1                     1
# 39        Gastric ulcer                     1                     0
#
#     Abscess (Collection of pus)  Alcohol abuse  Anxiety (Nervousness)  \
# 0                             0              0                      0
# 11                            0              0                      0
# 15                            0              0                      0
# 28                            0              0                      0
# 39                            0              1                      0
#
#     Arm ache or pain  Back ache or pain  Bleeding tendency  Blood in vomit  \
# 0                  0                  1                  0               0
# 11                 0                  0                  0               0
# 15                 0                  1                  0               0
# 28                 0                  0                  0               0
# 39                 0                  0                  0               0
#
#     ...  Neck stiffness or tightness  Agitated  Confusion  \
# 0   ...                            0         0          0
# 11  ...                            0         0          0
# 15  ...                            0         0          0
# 28  ...                            0         0          0
# 39  ...                            0         0          0
#
#     Headache and weakness  Confusion and headache  Nipple discharge  \
# 0                       0                       0                 0
# 11                      0                       0                 0
# 15                      0                       0                 0
# 28                      0                       0                 0
# 39                      0                       0                 0
#
#     Shoulder stiffness or tightness  Arm stiffness or tightness  \
# 0                                 0                           0
# 11                                0                           0
# 15                                0                           0
# 28                                0                           0
# 39                                0                           0
#
#     High blood pressure  High blood sugar
# 0                     0                 0
# 11                    0                 0
# 15                    0                 0
# 28                    0                 0
# 39                    0                 0
#
# [5 rows x 247 columns]
